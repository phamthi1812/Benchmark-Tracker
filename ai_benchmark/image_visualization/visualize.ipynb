# %%
import csv
import os
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sb
#plt.style.use('classic')
plt.style.use('ggplot')
sb.set_theme(style="whitegrid")

# %%
HOME = os.environ['HOME']

# %% [markdown]
# ## RESULTS + logPath7

# %%
data_infe1 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS/results_inference.csv')
data_train1 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS/results_training.csv')

# %%
data_infe2 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS2/results_inference.csv')
data_train2 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS2/results_training.csv')

# %%
data_infe3 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS3/results_inference.csv')
data_train3 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS3/results_training.csv')

# %%
data_infe4 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS4/results_inference.csv')
data_train4 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS4/results_training.csv')

# %%
data_infe5 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS5/results_inference.csv')
data_train5 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS5/results_training.csv')

# %%
data_infe6 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS6/results_inference.csv')
data_train6 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS6/results_training.csv')

# %%
data_infe7 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS7/results_inference.csv')
data_train7 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS7/results_training.csv')

# %%
data_infe8 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS8/results_inference.csv')
data_train8 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS8/results_training.csv')

# %%
data_infe9 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS9/results_inference.csv')
data_train9 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS9/results_training.csv')

# %%
data_infe10 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS10/results_inference.csv')
data_train10 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS10/results_training.csv')

# %% [markdown]
# - test 8,9,10,11,12 have 2 inference tests => 24 TESTS IN TOTAL

# %%
data_infe1 = data_infe1.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])
data_infe1 = data_infe1.drop(columns="tool_PUE")
data_infe2 = data_infe2.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])
data_infe2 = data_infe2.drop(columns="tool_PUE")
#data_infe3 = data_infe3.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])
#data_infe3 = data_infe3.drop(columns="tool_PUE")
#data_infe4 = data_infe4.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])
#data_infe4 = data_infe4.drop(columns="tool_PUE")
data_infe5 = data_infe5.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])
data_infe5 = data_infe5.drop(columns="tool_PUE")
data_infe6 = data_infe6.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])
data_infe6 = data_infe6.drop(columns="tool_PUE")
data_infe7 = data_infe7.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])
data_infe7 = data_infe7.drop(columns="tool_PUE")
data_infe8 = data_infe8.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])
data_infe8 = data_infe8.drop(columns="tool_PUE")
data_infe9 = data_infe9.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])
data_infe9 = data_infe9.drop(columns="tool_PUE")
data_infe10 = data_infe10.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])
data_infe10 = data_infe10.drop(columns="tool_PUE")

# %%
data_infe_class1 = data_infe1[0:7]
data_infe_class2 = data_infe2[0:7]
data_infe_class5 = data_infe5[0:7]
data_infe_class6 = data_infe6[0:7]
data_infe_class7 = data_infe7[0:7]
data_infe_class8 = data_infe8[0:7]
data_infe_class9 = data_infe9[0:7]
data_infe_class10 = data_infe10[0:7]

# %%
data_train1 = data_train1.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5','VGG-19','ResNet-SRGAN','ResNet-DPED','U-Net','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM'])
data_train1= data_train1.drop(columns="tool_PUE")
data_train2 = data_train2.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5','VGG-19','ResNet-SRGAN','ResNet-DPED','U-Net','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM'])
data_train2= data_train2.drop(columns="tool_PUE")
data_train5 = data_train5.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5','VGG-19','ResNet-SRGAN','ResNet-DPED','U-Net','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM'])
data_train5= data_train5.drop(columns="tool_PUE")
data_train6 = data_train6.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5','VGG-19','ResNet-SRGAN','ResNet-DPED','U-Net','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM'])
data_train6= data_train6.drop(columns="tool_PUE")
data_train7 = data_train7.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5','VGG-19','ResNet-SRGAN','ResNet-DPED','U-Net','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM'])
data_train7= data_train7.drop(columns="tool_PUE")
data_train8 = data_train8.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5','VGG-19','ResNet-SRGAN','ResNet-DPED','U-Net','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM'])
data_train8= data_train8.drop(columns="tool_PUE")
data_train9 = data_train9.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5','VGG-19','ResNet-SRGAN','ResNet-DPED','U-Net','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM'])
data_train9= data_train9.drop(columns="tool_PUE")
data_train10 = data_train10.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5','VGG-19','ResNet-SRGAN','ResNet-DPED','U-Net','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM'])
data_train10= data_train10.drop(columns="tool_PUE")

# %%
data_train_class1 = data_train1[0:7]
data_train_class2 = data_train2[0:7]
data_train_class5 = data_train5[0:7]
data_train_class6 = data_train6[0:7]
data_train_class7 = data_train7[0:7]
data_train_class8 = data_train8[0:7]
data_train_class9 = data_train9[0:7]
data_train_class10 = data_train10[0:7]

# %%
infe_class1 = data_infe_class1.append(data_infe_class2)
infe_class2 = infe_class1.append(data_infe_class5)
infe_class3 = infe_class2.append(data_infe_class6)
infe_class4 = infe_class3.append(data_infe_class7)
infe_class5 = infe_class4.append(data_infe_class8)
infe_class6 = infe_class5.append(data_infe_class9)
infe_class7 = infe_class6.append(data_infe_class10)
infe_class7
# Out:
#                      tool_energy_consumption(kWh)  \
# MobileNet-V2                             0.001225
# Inception-V3                             0.001991
# Inception-V4                             0.002664
# Inception-ResNet-V2                      0.002595
# ResNet-V2-50                             0.002268
# ResNet-V2-152                            0.002610
# VGG-16                                   0.002934
# MobileNet-V2                             0.001202
# Inception-V3                             0.002014
# Inception-V4                             0.002538
# Inception-ResNet-V2                      0.002565
# ResNet-V2-50                             0.002397
# ResNet-V2-152                            0.002786
# VGG-16                                   0.002903
# MobileNet-V2                             0.001112
# Inception-V3                             0.001971
# Inception-V4                             0.002489
# Inception-ResNet-V2                      0.002489
# ...

# %%
train_class1 = data_train_class1.append(data_train_class2)
train_class2 = train_class1.append(data_train_class5)
train_class3 = train_class2.append(data_train_class6)
train_class4 = train_class3.append(data_train_class7)
train_class5 = train_class4.append(data_train_class8)
train_class6 = train_class5.append(data_train_class9)
train_class7 = train_class6.append(data_train_class10)
train_class7
# Out:
#                      tool_energy_consumption(kWh)  \
# MobileNet-V2                             0.001721
# Inception-V3                             0.003226
# Inception-V4                             0.003632
# Inception-ResNet-V2                      0.004158
# ResNet-V2-50                             0.002373
# ResNet-V2-152                            0.004035
# VGG-16                                   0.001974
# MobileNet-V2                             0.001698
# Inception-V3                             0.002901
# Inception-V4                             0.003670
# Inception-ResNet-V2                      0.003938
# ResNet-V2-50                             0.002422
# ResNet-V2-152                            0.004245
# VGG-16                                   0.001311
# MobileNet-V2                             0.001688
# Inception-V3                             0.003023
# Inception-V4                             0.003769
# Inception-ResNet-V2                      0.003904
# ...

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x= infe_class7.index, y="tool_energy_consumption(kWh)", data=infe_class7)
plt.xticks(fontsize=12, rotation=90)
plt.title('Energy Consumption in Inference for Classification Models',size=18)
plt.xlabel("Models", size=15)
plt.ylabel("Energy consumption (kWh)", size=15)
plt.savefig('image/infe_energy_class.pdf',bbox_inches = 'tight')

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x= train_class7.index, y="tool_energy_consumption(kWh)", data=train_class7)
plt.xticks(fontsize=12, rotation=90)
plt.title('Energy Consumption in Training for Classification Models',size=18)
plt.xlabel("Classificaton Models", size=15)
plt.ylabel("Energy consumption (kWh)", size=15)
plt.savefig('image/train_energy_class.pdf',bbox_inches = 'tight')

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x= infe_class7.index, y="tool_energy_consumption(kWh)", data=infe_class7)
plt.xticks(fontsize=12, rotation=90)
plt.title('Energy Consumption in Inference for Classification Models',size=18)
plt.xlabel("Classificaton Models", size=15)
plt.ylabel("Energy consumption (kWh)", size=15)
plt.savefig('image/infe_energy_class.pdf',bbox_inches = 'tight')

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x= infe_class7.index, y="tool_duration(seconds)", data=infe_class7)
plt.xticks(fontsize=12, rotation=90)
plt.title('Duration In Inference for Classification Models',size=18)
plt.xlabel("Classification Models", size=15)
plt.ylabel("Duration (seconds)", size=15)
plt.savefig('image/infe_du_class.pdf',bbox_inches = 'tight')

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x= train_class7.index, y="tool_duration(seconds)", data=train_class7)
plt.xticks(fontsize=12, rotation=90)
plt.title('Duration In Training for Classification Models',size=18)
plt.xlabel("Classification Models", size=15)
plt.ylabel("Duration(seconds)", size=15)
plt.savefig('image/train_du_class.pdf',bbox_inches = 'tight')

# %%
data_infe =( data_infe1 +data_infe2+data_infe5+data_infe6+data_infe7+data_infe8+data_infe10+data_infe9)/8
data_infe

# %%
data_train = (data_train1 +data_train2 +data_train5+data_train6+data_train7+data_train8+data_train9+data_train10)/8
data_train

# %% [markdown]
# - test 19 has no training test => 18 TESTS IN TOTAL

# %% [markdown]
# ### VISUALIZE

# %%
data_infe_class = data_infe[0:7]
data_infe_class

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x=data_infe_class.index,y =data_infe_class['tool_energy_consumption(kWh)'],data = data_infe_class)
ax.tick_params(axis='x', rotation=30)
plt.title('Energy consumption in inference for classification',size=18)
plt.xlabel("Classification Models", size=15)
plt.ylabel("Energy consumption (kWh)", size=15)
plt.savefig('image/infe_class_energy.pdf',bbox_inches = 'tight')

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x=data_infe_class.index,y =data_infe_class['tool_duration(seconds)'],data = data_infe_class)
ax.tick_params(axis='x', rotation=30)
plt.title('Duration in inference for classification',size=18)
plt.xlabel("Classification Models", size=15)
plt.ylabel("Duration (seconds)", size=15)
plt.savefig('image/infe_class_du.pdf',bbox_inches = 'tight')

# %%
data_train_class = data_train[0:7]
data_train_class

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x=data_train_class.index,y =data_train_class['tool_duration(seconds)'],data = data_train_class)
ax.tick_params(axis='x', rotation=30)
plt.title('Duration in training for classification',size=18)
plt.xlabel("Classification Models", size=15)
plt.ylabel("Duration (seconds)", size=15)
plt.savefig('image/train_class_du.pdf',bbox_inches = 'tight')

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x=data_train_class.index,y =data_train_class['tool_energy_consumption(kWh)'],data = data_train_class)
ax.tick_params(axis='x', rotation=30)
plt.title('Energy consumption in training for classification',size=18)
plt.xlabel("Classification Models", size=15)
plt.ylabel("Energy consumption (kWh)", size=15)
plt.savefig('image/train_class_energy.pdf',bbox_inches = 'tight')

# %%
infe1 = data_infe1.append(data_infe2)
infe2 = infe1.append(data_infe5)
infe3 = infe2.append(data_infe6)
infe4 = infe3.append(data_infe7)
infe5 = infe4.append(data_infe8)
infe6 = infe5.append(data_infe9)
infe7 = infe6.append(data_infe10)
infe7

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x= infe7.index, y="tool_energy_consumption(kWh)", data=infe7)
plt.xticks(fontsize=12, rotation=90)
plt.title('Energy consumption in inference',size=18)
plt.xlabel("Models", size=15)
plt.ylabel("Energy consumption (kWh)", size=15)
plt.savefig('image/infe_energy.pdf',bbox_inches = 'tight')

# %%
infe_class = []
for row in infe7:
    if(( infe7.index == 'MobileNet-V2') or (infe7.index =='Inception-V3')or(infe7.index =='Inception-V4')or(infe7.index =='Inception-ResNet-V2')or(infe7.index =='ResNet-V2-50')or(infe7.index =='ResNet-V2-152')or(infe7.index =='VGG-16')):
        infe_class.append(row)

infe_class_df = pd.DataFrame(infe_class)

# %%
train1 = data_train1.append(data_train2)
train2 = train1.append(data_train5)
train3 = train2.append(data_train6)
train4 = train3.append(data_train7)
train5 = train4.append(data_train8)
train6 = train5.append(data_train9)
train7 = train6.append(data_train10)
train7

# %%
plt.figure(figsize=(12,8))
ax= sb.barplot(x= train7.index, y="tool_energy_consumption(kWh)", data=train7)
plt.xticks(fontsize=12, rotation=90)
plt.title('Energy consumption in training',size=18)
plt.xlabel("Models", size=15)
plt.ylabel("Energy consumption (kWh)", size=15)
plt.savefig('image/train_energy.pdf',bbox_inches = 'tight')

# %%
data_train_class['tool_energy_consumption(kWh)'].plot.barh()
plt.title('Energy consumption in training (kWh) ')
plt.savefig('RESULTS/train_energy_class.jpg')
plt.show()

# %%
data_train_class['tool_duration(seconds)'].plot.barh()
plt.title('Duration in training for classification (seconds)')
plt.savefig('RESULTS/train_duration_class.jpg')
plt.show()

# %% [markdown]
# #### 1.INFERENCE

# %%
data_infe['tool_energy_consumption(kWh)'].plot.barh()
plt.title('Energy consumption in inference (kWh) ')
plt.savefig('RESULTS/infe_energy.jpg')
#plt.savefig('RESULTS/infe_energy.pdf')
plt.show()

# %%
data_infe['tool_carbon_emissions(kgC02eq)'].plot.barh()
plt.title('Carbon emissions in inference (kgC02eq) ')
plt.savefig('RESULTS/infe_carbon.jpg')
#plt.savefig('RESULTS/infe_carbon.pdf')
plt.show()

# %%
data_infe['tool_duration(seconds)'].plot.barh()
plt.title('Duration in inference (seconds) ')
plt.savefig('RESULTS/infe_duration.jpg')
plt.show()

# %% [markdown]
# #### 2. TRAINING

# %%
data_train['tool_energy_consumption(kWh)'].plot.barh()
plt.title('Energy consumption in training (kWh) ')
plt.savefig('RESULTS/train_energy.jpg')
plt.show()

# %%
data_train['tool_carbon_emissions(kgC02eq)'].plot.barh()
plt.title('Carbon emissions in training (kgC02eq) ')
plt.savefig('RESULTS/train_carbon.jpg')
plt.show()

# %%
data_train['tool_duration(seconds)'].plot.barh()
plt.title('Duration in training (seconds)')
plt.savefig('RESULTS/train_duration.jpg')
plt.show()

# %% [markdown]
# ### RESULTS2 + logPath8

# %%
data_infe2 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS2/results_inference.csv')
data_train2 = pd.read_csv(HOME +'/research_project/benchmark-tracker/ai_benchmark/RESULTS2/results_training.csv')

# %%
data_infe2 = data_infe2.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5_1','SRCNN 9-5-5_2','VGG-19_1','VGG-19_2','ResNet-SRGAN_1','ResNet-SRGAN_2','ResNet-DPED_1','ResNet-DPED_2','U-Net_1','U-Net_2','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM','GNMT'])

# %%
data_train2 = data_train2.set_axis(['MobileNet-V2','Inception-V3','Inception-V4','Inception-ResNet-V2','ResNet-V2-50','ResNet-V2-152','VGG-16','SRCNN 9-5-5','VGG-19','ResNet-SRGAN','ResNet-DPED','U-Net','Nvidia-SPADE','ICNet','PSPNet','DeepLab','Pixel-RNN','LSTM'])

# %%
data_infe2['tool_energy_consumption(kWh)'].plot.barh()
plt.title('Energy consumption in inference (kWh) ')
plt.savefig('RESULTS2/infe_energy.jpg')
plt.show()

# %%
data_infe2['tool_carbon_emissions(kgC02eq)'].plot.barh()
plt.title('Carbon emissions in inference (kgC02eq) ')
plt.savefig('RESULTS2/infe_carbon.jpg')
plt.show()

# %%
data_infe2['tool_duration(seconds)'].plot.barh()
plt.title('Duration in inference (seconds) ')
plt.savefig('RESULTS2/infe_duration.jpg')
plt.show()

# %%
data_train2['tool_energy_consumption(kWh)'].plot.barh()
plt.title('Energy consumption in training (kWh) ')
plt.savefig('RESULTS2/train_energy.jpg')
plt.show()

# %%
data_train2['tool_carbon_emissions(kgC02eq)'].plot.barh()
plt.title('Carbon emissions in training (kgC02eq) ')
plt.savefig('RESULTS2/train_carbon.jpg')
plt.show()

# %%
data_train2['tool_duration(seconds)'].plot.barh()
plt.title('Duration in training (seconds)')
plt.savefig('RESULTS2/train_duration.jpg')
plt.show()

# %% [markdown]
# ### Run several time for sure the results is stable ! and yeah They are !
